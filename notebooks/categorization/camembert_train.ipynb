# %%
# Common and Infer 
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from transformers import CamembertTokenizer, CamembertForSequenceClassification
import pickle
import warnings
warnings.simplefilter("ignore")

#Training Imports
from sklearn.metrics import classification_report
from transformers import AdamW, get_linear_schedule_with_warmup

#optional to be used for monitoring training
import wandb 
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
my_secret = user_secrets.get_secret("wandb_api_key")

class CFG:
    model_name = 'camembert-base'
    base_path = '/kaggle/input/ecommerce-recategorize/'
    dataset_name = 'category_data_unique_title'
    save_dir = '/kaggle/working/model/'
    encoder_name = 'label_encoder' #for saving the encoder
    batch_size = 8
    max_length = 40
    learning_rate = 2e-5
    epochs = 15
    do_monitoring = True

# %%
def load_data(base_path, dataset_name):
    df = pd.read_csv(f'{base_path}/{dataset_name}.csv')
    return df

def preprocess_data(df):
    le = LabelEncoder()
    df['Nature_encoded'] = le.fit_transform(df['Nature'])
    return df, le

def compute_class_weights(df):
    class_weights = compute_class_weight('balanced', classes=df['Nature_encoded'].unique(), y=df['Nature_encoded'])
    return torch.tensor(class_weights, dtype=torch.float)

def split_data(df, test_size=0.2, random_state=42):
    return train_test_split(df['Libellé produit'], df['Nature_encoded'], test_size=test_size, random_state=random_state)

def encode_texts(texts, tokenizer, max_length=CFG.max_length):
    return tokenizer.batch_encode_plus(
        texts.tolist(),
        max_length=max_length,
        padding="max_length",
        truncation=True,
        return_attention_mask=True
    )

# %%
# Trainer 
class CamembertTrainer:
    def __init__(self, model_name, base_path, dataset_name, batch_size=CFG.batch_size, max_length=CFG.max_length, do_monitoring=CFG.do_monitoring):
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.model_name = model_name
        self.batch_size = batch_size
        self.max_length = max_length
        
        self.df = load_data(base_path, dataset_name)
        self.df, self.le = preprocess_data(self.df)
        self.class_weights = compute_class_weights(self.df).to(self.device)
        
        self.X_train, self.X_test, self.y_train, self.y_test = split_data(self.df)
        
        self.tokenizer = CamembertTokenizer.from_pretrained(self.model_name)
        if self.tokenizer.pad_token is None:
            self.tokenizer.add_special_tokens({'pad_token': '[PAD]'})
            
        self.train_encodings = encode_texts(self.X_train, self.tokenizer, self.max_length)
        self.test_encodings = encode_texts(self.X_test, self.tokenizer, self.max_length)
        
        self.train_dataset = TensorDataset(
            torch.tensor(self.train_encodings['input_ids']),
            torch.tensor(self.train_encodings['attention_mask']),
            torch.tensor(self.y_train.tolist())
        )
        
        self.test_dataset = TensorDataset(
            torch.tensor(self.test_encodings['input_ids']),
            torch.tensor(self.test_encodings['attention_mask']),
            torch.tensor(self.y_test.tolist())
        )
        
        self.train_dataloader = DataLoader(self.train_dataset, sampler=RandomSampler(self.train_dataset), batch_size=self.batch_size)
        self.test_dataloader = DataLoader(self.test_dataset, sampler=SequentialSampler(self.test_dataset), batch_size=self.batch_size)
        
        self.model = CamembertForSequenceClassification.from_pretrained(self.model_name, num_labels=len(self.le.classes_))
        self.model.to(self.device)
        
        self.optimizer = AdamW(self.model.parameters(), lr=CFG.learning_rate)
        total_steps = len(self.train_dataloader) * CFG.epochs  # 15 epochs
        self.scheduler = get_linear_schedule_with_warmup(self.optimizer, num_warmup_steps=int(total_steps * 0.1), num_training_steps=total_steps)
        
        self.do_monitoring = do_monitoring
        
        if self.do_monitoring:
            wandb.login(key=my_secret)
            wb_config = dict(max_length = CFG.max_length,learning_rate = CFG.learning_rate,epochs = CFG.epochs)
            wandb.init(project="camabert-product-categorization", entity="jztinchawda", config= wb_config)  
        
    def compute_loss(self, inputs, return_outputs=False):
        labels = inputs.pop("labels").to(self.device)
        outputs = self.model(**inputs)
        logits = outputs.logits.to(self.device)
        loss_fn = nn.CrossEntropyLoss(weight=self.class_weights)
        loss = loss_fn(logits, labels)
        return (loss, outputs) if return_outputs else loss

    def evaluate(self, dataloader):
        self.model.eval()
        total_loss = 0
        total_correct = 0
        total_predictions = 0
        
        for batch in dataloader:
            batch = tuple(t.to(self.device) for t in batch)
            inputs = {'input_ids': batch[0], 'attention_mask': batch[1], 'labels': batch[2]}
            
            with torch.no_grad():
                loss, outputs = self.compute_loss(inputs, return_outputs=True)
            
            total_loss += loss.item()
            logits = outputs.logits
            predictions = torch.argmax(logits, dim=-1)
            total_correct += torch.sum(predictions == batch[2]).item()
            total_predictions += batch[2].size(0)
        
        avg_loss = total_loss / len(dataloader)
        accuracy = total_correct / total_predictions
        return avg_loss, accuracy
    
    def generate_classification_report(self):
        self.model.eval()
        predictions = []
        true_labels = []

        for batch in self.test_dataloader:
            batch = tuple(t.to(self.device) for t in batch)
            inputs = {'input_ids': batch[0], 'attention_mask': batch[1]}
            
            with torch.no_grad():
                outputs = self.model(**inputs)
            
            logits = outputs.logits
            predictions.extend(torch.argmax(logits, dim=1).cpu().numpy())
            true_labels.extend(batch[2].cpu().numpy())

        
        true_labels = np.array(true_labels)
        predictions = np.array(predictions)

        
        unique_labels = np.unique(true_labels)
        predicted_labels = np.unique(predictions)
        labels = np.unique(np.concatenate([unique_labels, predicted_labels]))

        
        print(classification_report(true_labels, predictions, labels=labels, target_names=self.le.classes_))
    
    def train(self, epochs=CFG.epochs, early_stopping_patience=3):
        best_val_loss = float('inf')
        patience_counter = 0
        
        for epoch in range(epochs):
            self.model.train()
            total_loss = 0
            total_correct = 0
            total_predictions = 0
            
            for batch in self.train_dataloader:
                batch = tuple(t.to(self.device) for t in batch)
                inputs = {'input_ids': batch[0], 'attention_mask': batch[1], 'labels': batch[2]}
                
                self.optimizer.zero_grad()
                loss, outputs = self.compute_loss(inputs, return_outputs=True)
                total_loss += loss.item()
                logits = outputs.logits
                predictions = torch.argmax(logits, dim=-1)
                total_correct += torch.sum(predictions == batch[2]).item()
                total_predictions += batch[2].size(0)
                
                loss.backward()
                torch.nn.utils.clip_grad_norm_(self.model.parameters(), 1.0)
                self.optimizer.step()
                self.scheduler.step()
            
            avg_train_loss = total_loss / len(self.train_dataloader)
            train_accuracy = total_correct / total_predictions
            
            val_loss, val_accuracy = self.evaluate(self.test_dataloader)
            
            print(f"Epoch {epoch+1}")
            print(f"Average training loss: {avg_train_loss:.4f} | Training accuracy: {train_accuracy:.4f}")
            print(f"Validation loss: {val_loss:.4f} | Validation accuracy: {val_accuracy:.4f}")
            
            if self.do_monitoring:
                wandb.log({
                'epoch': epoch + 1,
                'train_loss': avg_train_loss,
                'train_accuracy': train_accuracy,
                'val_loss': val_loss,
                'val_accuracy': val_accuracy
            })
            
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                patience_counter = 0
                trainer.save_model(f'{CFG.save_dir}/{CFG.model_name}', f'{CFG.save_dir}/{CFG.model_name}', f'{CFG.save_dir}/{CFG.encoder_name}.pkl')
            else:
                patience_counter += 1
                print(f'Triggered Patience with {patience_counter}')
                if patience_counter >= early_stopping_patience:
                    print("Early stopping triggered.")
                    break
                    
        
        print("Training complete!")
        self.generate_classification_report()

    def save_model(self, model_path, tokenizer_path, label_encoder_path):
        self.model.save_pretrained(model_path)
        self.tokenizer.save_pretrained(tokenizer_path)
        
        with open(label_encoder_path, "wb") as f:
            pickle.dump(self.le, f)

# %%
trainer = CamembertTrainer(model_name=CFG.model_name, base_path=CFG.base_path, dataset_name=CFG.dataset_name)
trainer.train()
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/811k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.40M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/508 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# model.safetensors:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of CamembertForSequenceClassification were not initialized from the model checkpoint at camembert-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: jztinchawda. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.4
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20240714_125231-v0iogrvi
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run wise-gorge-28
# wandb: ⭐️ View project at https://wandb.ai/jztinchawda/camabert-product-categorization
# wandb: 🚀 View run at https://wandb.ai/jztinchawda/camabert-product-categorization/runs/v0iogrvi
# Epoch 1
# Average training loss: 5.2849 | Training accuracy: 0.0388
# Validation loss: 3.7981 | Validation accuracy: 0.1301
# Epoch 2
# Average training loss: 2.6259 | Training accuracy: 0.3126
# Validation loss: 1.7688 | Validation accuracy: 0.5035
# Epoch 3
# Average training loss: 1.4124 | Training accuracy: 0.5658
# Validation loss: 1.2068 | Validation accuracy: 0.6190
# Epoch 4
# Average training loss: 0.9721 | Training accuracy: 0.6510
# Validation loss: 1.0115 | Validation accuracy: 0.6774
# Epoch 5
# Average training loss: 0.7547 | Training accuracy: 0.7023
# Validation loss: 0.9188 | Validation accuracy: 0.7137
# Epoch 6
# Average training loss: 0.6155 | Training accuracy: 0.7427
# Validation loss: 0.8691 | Validation accuracy: 0.7283
# Epoch 7
# Average training loss: 0.5035 | Training accuracy: 0.7750
# Validation loss: 0.8502 | Validation accuracy: 0.7521
# Epoch 8
# Average training loss: 0.4171 | Training accuracy: 0.8014
# Validation loss: 0.8502 | Validation accuracy: 0.7641
# Triggered Patience with 1
# Epoch 9
# Average training loss: 0.3559 | Training accuracy: 0.8225
# Validation loss: 0.8530 | Validation accuracy: 0.7781
# Triggered Patience with 2
# Epoch 10
# Average training loss: 0.3028 | Training accuracy: 0.8407
# Validation loss: 0.8424 | Validation accuracy: 0.7860
# Epoch 11
# Average training loss: 0.2644 | Training accuracy: 0.8584
# Validation loss: 0.8386 | Validation accuracy: 0.7878
# Epoch 12
# Average training loss: 0.2249 | Training accuracy: 0.8694
# Validation loss: 0.8436 | Validation accuracy: 0.7935
# Triggered Patience with 1
# Epoch 13
# Average training loss: 0.2004 | Training accuracy: 0.8795
# Validation loss: 0.8497 | Validation accuracy: 0.7976
# Triggered Patience with 2
# Epoch 14
# Average training loss: 0.1832 | Training accuracy: 0.8890
# Validation loss: 0.8545 | Validation accuracy: 0.8012
# Triggered Patience with 3
# Early stopping triggered.
# Training complete!
#                              precision    recall  f1-score   support
#
#                   abat jour       0.00      0.00      0.00         4
#                 abattant wc       0.85      0.92      0.88        12
#              abri de jardin       0.00      0.00      0.00         9
#              acc telephonie       0.84      0.71      0.77        98
#         access motorisation       0.00      0.00      0.00         8
#          access photo video       0.00      0.00      0.00        28
#         access. pc tablette       0.64      0.78      0.71        23
#        accessoire allaitem.       0.17      0.50      0.25         2
#             accessoire aspi       0.00      0.00      0.00         2
#        accessoire autoradio       0.00      0.00      0.00         1
#           accessoire balneo       0.00      0.00      0.00         1
#         accessoire barbecue       0.00      0.00      0.00        17
#          accessoire biberon       1.00      0.21      0.35        14
#           accessoire biblio       0.00      0.00      0.00         1
#           accessoire bureau       0.73      0.56      0.63        34
#          accessoire camping       0.00      0.00      0.00         2
#         accessoire cave vin       0.00      0.00      0.00         4
#        accessoire ch adulte       0.00      0.00      0.00         2
#        accessoire ch enfant       0.62      0.64      0.63        25
#         accessoire cheminee       0.00      0.00      0.00         3
#          accessoire cloture       0.00      0.00      0.00         1
#          accessoire cuisine       0.00      0.00      0.00        20
#          accessoire cuisson       0.66      0.73      0.69        26
#        accessoire de voyage       1.00      0.20      0.33         5
#         accessoire deguisem       0.00      0.00      0.00         2
#         accessoire dressing       0.00      0.00      0.00        20
#          accessoire fitness       0.50      0.33      0.40        18
#            accessoire froid       0.00      0.00      0.00         2
#           accessoire glisse       0.69      0.86      0.77        21
#           accessoire jardin       0.00      0.00      0.00         1
#        accessoire jeu video       1.00      0.25      0.40         4
#        accessoire jeux cafe       0.40      0.21      0.28        19
#         accessoire jeux ext       0.27      0.60      0.37         5
#           accessoire lavage       0.00      0.00      0.00         2
#          accessoire literie       0.00      0.00      0.00         1
#        accessoire luminaire       0.00      0.00      0.00         1
#              accessoire pem       0.48      0.46      0.47        24
#          accessoire piscine       1.00      0.33      0.50         6
#          accessoire plomber       0.00      0.00      0.00         2
#           accessoire poupee       0.00      0.00      0.00         1
#        accessoire poussette       0.00      0.00      0.00        14
#              accessoire sdb       0.00      0.00      0.00         7
#           accessoire sejour       0.00      0.00      0.00         3
#        accessoire siegeauto       0.69      0.69      0.69        13
#            accessoire soins       0.00      0.00      0.00         1
#            accessoire tapis       0.00      0.00      0.00         3
#          accessoire textile       1.00      0.25      0.40         4
#             accessoire velo       0.90      0.82      0.86        22
#        accessoire videoproj       1.00      0.33      0.50         3
#               accessoire wc       0.22      0.67      0.33         3
#              adaptateur tnt       1.00      1.00      1.00         2
#            alarme de maison       0.90      1.00      0.95         9
#               amplificateur       0.00      0.00      0.00         3
#                     ampoule       0.50      0.43      0.46        14
#                  antenne tv       0.82      0.78      0.80        18
#             appareil  photo       0.96      0.96      0.96        24
#           appareil a fondue       0.56      0.36      0.43        28
#         appareil a raclette       0.35      0.78      0.48         9
#           appareil a souder       0.00      0.00      0.00         5
#          appareil convivial       0.33      0.17      0.22         6
#        appareil musculation       0.00      0.00      0.00        27
#         appareils a coiffer       0.57      0.80      0.67         5
#                    applique       1.00      0.06      0.11        17
#                arche de jeu       0.00      0.00      0.00         1
#           archive brun-gris       1.00      0.55      0.71        11
#                     armoire       0.00      0.00      0.00        14
#           armoire de jardin       0.53      0.45      0.49        20
#                 armoire lit       0.74      0.76      0.75        34
#                    arrosage       0.00      0.00      0.00         2
#           article de menage       0.86      0.86      0.86         7
#            aspirateur balai       0.50      0.40      0.44         5
#            aspirateur robot       0.00      0.00      0.00         3
#         aspirateur traineau       0.00      0.00      0.00         2
#          assist tel payante       0.83      1.00      0.91         5
#                 autocuiseur       0.73      0.88      0.80        25
#                  autoportee       0.00      0.00      0.00         3
#                   autoradio       0.00      0.00      0.00         4
#               autre cuisson       0.50      1.00      0.67         3
#        autre prep culinaire       0.30      0.75      0.43         4
#         autre soin personne       0.67      0.22      0.33         9
#                      auvent       0.76      0.81      0.79        16
#                    babyfoot       0.00      0.00      0.00         6
#                   babyphone       0.63      0.65      0.64        26
#                 bac a sable       0.68      0.62      0.65        34
#                   baignoire       0.73      0.90      0.81        21
#              baignoire bebe       0.50      1.00      0.67         4
#              bain de soleil       1.00      1.00      1.00         3
#              baladeur mp3/4       0.87      1.00      0.93        13
#                balai vapeur       1.00      0.20      0.33         5
#          balance de cuisine       0.33      0.50      0.40         2
#             balancelle bebe       0.00      0.00      0.00         1
#        balancelle de jardin       1.00      0.38      0.55         8
#                  balancoire       0.25      0.50      0.33         4
#                        banc       0.80      0.85      0.82       133
#                 banc de lit       0.75      0.75      0.75         4
#                   banquette       0.78      0.78      0.78         9
#                         bar       1.00      1.00      1.00         2
#                    barbecue       0.67      0.62      0.65        69
#                barre de son       0.56      0.59      0.57        17
#            barrette memoire       0.38      0.45      0.42        11
#        barriere de securite       1.00      0.75      0.86         4
#                      bassin       0.67      0.33      0.44         6
#         batterie de cuisine       1.00      0.82      0.90        11
#                     batteur       1.00      0.85      0.92        20
#                      bavoir       1.00      0.60      0.75         5
#                     berceau       0.78      0.70      0.74        10
#                     biberon       0.73      0.82      0.77        95
#                bibliotheque       0.80      0.64      0.71        25
#                     billard       0.94      0.97      0.95       203
#                     blender       0.00      0.00      0.00         7
#           boite aux lettres       0.86      0.86      0.86         7
#          boite de rangement       0.90      0.97      0.94        75
#         boites conservation       0.80      0.86      0.83        28
#             boitier alim pc       0.72      0.67      0.69        27
#                boudin porte       0.00      0.00      0.00        14
#                    bougeoir       0.00      0.00      0.00         2
#                      bougie       0.00      0.00      0.00         2
#                  bouilloire       0.00      0.00      0.00         3
#                     brasero       0.69      0.67      0.68       134
#                   brise vue       0.82      0.58      0.68       149
#                      bucher       0.50      0.29      0.36         7
#                      buffet       0.00      0.00      0.00         1
#           buffet de cuisine       0.92      0.58      0.71        19
#                      bureau       0.00      0.00      0.00         4
#               cabane enfant       0.00      0.00      0.00         1
#            cabine de douche       0.67      1.00      0.80         4
#              cadre a lattes       0.61      0.73      0.67        15
#                 cadre photo       0.43      0.75      0.55         4
#            cafetiere filtre       0.16      0.60      0.25         5
#        cafetiere portionnee       0.79      0.87      0.83        30
#          caisson de cuisine       0.95      1.00      0.97        18
#                   cale bebe       1.00      0.50      0.67        10
#                camera sport       1.00      1.00      1.00         2
#         camera surveillance       0.71      0.50      0.59        10
#                   camescope       0.95      0.93      0.94       382
#              canape d'angle       0.94      0.96      0.95       135
#                canape droit       0.71      0.83      0.77         6
#                      carafe       0.59      0.89      0.71        19
#            carafe filtrante       0.88      0.70      0.78        10
#                    carpette       0.71      0.31      0.43        16
#                     carport       0.67      0.67      0.67         3
#             carte graphique       0.00      0.00      0.00         1
#               carte memoire       0.40      1.00      0.57         4
#                  carte mere       0.92      0.92      0.92       104
#                   cartouche       0.63      0.59      0.61        29
#              casque filaire       1.00      1.00      1.00         3
#             casque sans fil       0.86      1.00      0.92         6
#                   casserole       0.00      0.00      0.00         1
#                  cave a vin       0.77      0.81      0.79        21
#             centrale vapeur       0.00      0.00      0.00         4
#               centrifugeuse       1.00      0.80      0.89         5
#                chaine audio       0.75      0.75      0.75        32
#                      chaise       0.94      0.89      0.91        35
#            chaise de bureau       0.00      0.00      0.00         3
#           chaise haute bebe       0.88      0.64      0.74        11
#                    chargeur       0.65      0.80      0.72        30
#          chariot de courses       0.94      0.93      0.93       109
#         chauffage d'appoint       0.91      1.00      0.96        32
#             chauffe biberon       0.36      0.83      0.50        12
#                  chauffeuse       0.90      0.86      0.88        65
#         chaussures de sport       0.75      1.00      0.86         6
#              cheminee poele       0.70      0.86      0.77        35
#                      chevet       0.00      0.00      0.00         1
#                 chiffonnier       0.00      0.00      0.00         2
#                 ciel de lit       0.65      0.71      0.68        24
#                     cintres       0.00      0.00      0.00         1
#          circuit de voiture       0.00      0.00      0.00         1
#                     cireuse       0.00      0.00      0.00         4
#              clavier souris       1.00      1.00      1.00         2
#                     cle usb       0.43      1.00      0.60         3
#                 climatiseur       0.67      1.00      0.80         4
#                      coffre       0.17      0.50      0.25         2
#                   coiffeuse       0.82      0.93      0.87        15
#             colonne cuisine       0.90      0.90      0.90        21
#           colonne de douche       0.00      0.00      0.00         2
#                 colonne sdb       0.00      0.00      0.00         1
#                     commode       0.63      0.63      0.63        19
#                  composteur       0.00      0.00      0.00        11
#                 congelateur       0.00      0.00      0.00         1
#                 connectique       0.00      0.00      0.00         1
#                     console       0.71      1.00      0.83         5
#             console de jeux       0.81      0.79      0.80        33
#           cordon electrique       0.88      0.70      0.78        10
#                     couette       0.00      0.00      0.00         2
#                     couffin       0.56      1.00      0.71         5
#              coupe bordures       0.00      0.00      0.00         1
#                     coussin       0.88      0.90      0.89        71
#         coussin allaitement       0.67      0.71      0.69        34
#         coussin chaise bebe       0.57      0.73      0.64        11
#          couteau electrique       0.00      0.00      0.00         2
#                     couvert       0.64      0.75      0.69        12
#                    crepiere       0.50      0.60      0.55         5
#               croque gaufre       0.64      1.00      0.78         7
#              cube de jardin       0.81      0.85      0.83        20
#               cuiseur a riz       0.67      0.29      0.40         7
#              cuiseur vapeur       0.71      0.45      0.55        38
#            cuisine complete       0.00      0.00      0.00         1
#                  cuisiniere       0.64      0.75      0.69        12
#                 dalle ecran       0.69      0.53      0.60        17
#            debroussailleuse       0.00      0.00      0.00         2
#          decapeur thermique       0.00      0.00      0.00         2
#          decoration de noel       0.68      0.55      0.61        55
#         decoration de table       0.50      0.57      0.53        14
#                 deguisement       0.29      0.67      0.40         3
#                 deplimousse       0.82      0.90      0.86        20
#           deshumidificateur       0.00      0.00      0.00         1
#                    desserte       1.00      0.75      0.86         4
#               dessus de lit       0.40      0.67      0.50         3
#            dessus de meuble       0.78      0.82      0.80       119
#         detecteur mouvement       0.70      0.88      0.78         8
#                   diffuseur       0.83      0.83      0.83         6
#                  disque dur       0.43      1.00      0.60         6
#            douche de jardin       0.40      0.50      0.44         4
#                 drap housse       0.82      0.76      0.79       154
#                   drap plat       0.63      0.78      0.70        40
#            dressing complet       0.30      1.00      0.46         3
#          echarpe de portage       0.62      0.83      0.71         6
#          eclairage connecte       0.84      0.89      0.86        18
#         eclairage exterieur       0.67      0.67      0.67         3
#                   ecouteurs       0.91      0.86      0.89        36
#         ecran de projection       0.31      0.43      0.36        97
#                    ecran pc       0.68      0.88      0.77        17
#          electrostimulation       0.00      0.00      0.00         2
#             element bas sdb       0.33      1.00      0.50         1
#           element de bureau       0.50      0.33      0.40         3
#            element haut sdb       0.67      0.67      0.67         3
#          enceinte connectee       1.00      0.33      0.50         3
#                enceintes pc       0.00      0.00      0.00         2
#            ens buffet table       0.95      0.80      0.87        25
#           ens table chaises       0.00      0.00      0.00         2
#            ensemble chambre       0.62      0.73      0.67        11
#        ensemble home cinema       0.86      0.80      0.83        15
#                ensemble sdb       0.86      0.75      0.80         8
#                entretien pc       0.50      0.83      0.62         6
#               environnement       0.74      0.93      0.82        15
#                   epilateur       0.94      1.00      0.97        31
#                     etagere       1.00      0.95      0.97        76
#            etendoir a linge       0.50      0.25      0.33         4
#                       evier       0.00      0.00      0.00         2
#                    expresso       1.00      1.00      1.00         3
#           extracteur de jus       0.54      0.88      0.67         8
#           facade de cuisine       0.95      0.88      0.91       181
#                    fauteuil       0.80      0.79      0.79        70
#              fauteuil relax       0.67      1.00      0.80         4
#           fendeur de buches       0.00      0.00      0.00         1
#              fer a repasser       0.92      0.92      0.92        12
#           figurine et robot       1.00      0.33      0.50         3
#                 flash photo       0.00      0.00      0.00         2
#        fleurs artificielles       0.33      1.00      0.50         1
#                    fontaine       0.67      0.29      0.40         7
#                        four       0.61      0.79      0.69        28
#                    friteuse       0.64      0.94      0.76        17
#           galette de chaise       0.33      0.20      0.25        10
#                      garage       0.00      0.00      0.00         4
#          garant. excellence       0.75      0.60      0.67         5
#                    gaufrier       1.00      1.00      1.00         3
#           gazon synthetique       0.91      0.97      0.94        33
#                   gigoteuse       0.33      0.30      0.32        10
#                         gps       0.25      0.21      0.23        14
#                     graveur       0.50      0.22      0.31         9
#                    grillage       0.33      0.25      0.29         4
#                 grille pain       0.50      0.75      0.60         4
#               grille viande       0.50      0.83      0.62         6
#         guirlande lumineuse       0.00      0.00      0.00         1
#                    gyropode       0.94      0.97      0.95        61
#                     hachoir       1.00      0.50      0.67         4
#            haltere et poids       0.78      0.79      0.79        72
#                       hamac       0.79      0.69      0.73        16
#                      hammam       0.00      0.00      0.00         1
#                haut parleur       0.98      1.00      0.99        53
#                     horloge       1.00      1.00      1.00        36
#                       hotte       0.33      1.00      0.50         3
#                   housse bz       0.60      0.75      0.67         8
#               housse canape       0.89      0.87      0.88        45
#            housse clic-clac       0.80      0.80      0.80         5
#            housse de chaise       0.95      0.96      0.95       289
#           housse de couette       0.58      0.86      0.69        21
#           housse de coussin       0.94      0.93      0.93       218
#         housse de rangement       0.00      0.00      0.00         2
#         housse mobilier ext       0.60      0.75      0.67         4
#              housse sommier       0.00      0.00      0.00         1
#             housse vetement       0.40      0.57      0.47        14
#              humidificateur       0.93      0.65      0.76        20
#            hygiene dentaire       0.00      0.00      0.00         1
#              image encadree       1.00      1.00      1.00         6
#        image/affiche/poster       1.00      1.00      1.00         3
#                  imprimante       0.00      0.00      0.00         3
#        installation etagere       0.88      0.99      0.93       610
#      installation luminaire       0.93      0.93      0.93       162
#                  interphone       0.00      0.00      0.00         0
#             jeu d'imitation       0.14      0.33      0.20         3
#          jeu de carte et de       0.33      0.75      0.46         4
#         jeu de construction       0.77      0.83      0.80        12
#           jeu de flechettes       0.00      0.00      0.00         1
#                 jeu de pied       0.79      0.43      0.56       188
#              jeu de societe       0.89      0.86      0.88        29
#                jeu educatif       1.00      0.80      0.89        10
#            jeux d'exterieur       0.99      0.96      0.98       314
#                  jeux video       0.87      0.97      0.92        40
#               jouet 1er age       0.00      0.00      0.00         1
#               jouet de bain       0.03      0.50      0.06         2
#              jouet vehicule       0.59      0.67      0.63        24
#                    jumelles       0.93      0.87      0.90        15
#            lame de terrasse       0.55      0.46      0.50        13
#                  lampadaire       0.90      1.00      0.94        60
#          lampadaire liseuse       0.56      0.83      0.67         6
#                       lampe       1.00      0.65      0.79        26
#             lampe de bureau       0.33      1.00      0.50         1
#                      lavabo       0.00      0.00      0.00         1
#                  lave linge       0.00      0.00      0.00         7
#              lave vaisselle       0.00      0.00      0.00         2
#                 lecteur dvd       1.00      1.00      1.00         2
#        lecteur dvd portable       1.00      1.00      1.00         1
#              linge d'office       0.83      1.00      0.91        10
#              linge de table       0.00      0.00      0.00         1
#           linge de toilette       0.00      0.00      0.00         1
#                  lit adulte       1.00      0.78      0.88         9
#                    lit bebe       1.00      1.00      1.00         2
#                   lit jeune       1.00      1.00      1.00         3
#               lit parapluie       0.53      0.90      0.67        10
#                  lit pliant       0.60      0.75      0.67         4
#                  livre 5.5%       0.18      0.50      0.27         4
#            loisirs creatifs       0.65      0.61      0.63        80
#              luminotherapie       0.15      0.29      0.20         7
#                      lustre       0.84      0.90      0.87        29
#             machine a biere       0.42      0.23      0.29        22
#            machine a coudre       0.00      0.00      0.00         8
#              machine a pain       0.00      0.00      0.00         1
#                 marche pied       0.50      0.86      0.63         7
#                     matelas       0.63      0.60      0.62        20
#           matelas + sommier       0.61      0.88      0.72        16
#            matelas a langer       1.00      0.25      0.40         4
#               matelas futon       0.00      0.00      0.00         1
#           matelas gonflable       0.93      0.95      0.94        43
#            materiel camping       0.78      0.78      0.78        18
#            menagere couvert       1.00      0.75      0.86         4
#                  meridienne       0.84      1.00      0.91        21
#         meuble a chaussures       1.00      1.00      1.00         5
#          meuble bas cuisine       1.00      1.00      1.00        10
#         meuble haut cuisine       0.88      0.94      0.91        87
#                   meuble tv       0.57      0.73      0.64        11
#                       meule       0.74      0.89      0.81        19
#                 micro ondes       0.88      0.95      0.92        40
#                  microphone       0.00      0.00      0.00         1
#             mini aspirateur       0.50      0.56      0.53        16
#                mini commode       0.74      0.70      0.72        20
#                   mini four       0.60      1.00      0.75         3
#        mini mobilier enfant       0.75      0.75      0.75         4
#                      miroir       1.00      0.86      0.92         7
#               miroir psyche       0.70      0.65      0.67        46
#        miroir salle de bain       0.27      0.34      0.30        32
#                       mixer       0.88      0.94      0.91        67
#              mobile musical       1.00      0.25      0.40         4
#                   mobile nu       0.50      1.00      0.67         2
#                   modelisme       1.00      0.86      0.92         7
#             montage armoire       0.90      0.95      0.92        19
#           montage banquette       0.00      0.00      0.00         3
#        montage bibliotheque       0.82      0.97      0.89        34
#              montage bureau       0.00      0.00      0.00         2
#              montage canape       0.00      0.00      0.00         2
#            montage fauteuil       0.94      0.99      0.96        77
#                 montage lit       0.44      0.44      0.44         9
#          montage rangements       0.67      0.60      0.63        10
#               montage table       0.71      0.83      0.77         6
#          montre et bracelet       0.89      1.00      0.94        24
#         motoculteur bineuse       0.00      0.00      0.00         1
#          motorisation volet       0.00      0.00      0.00         6
#                       moule       0.00      0.00      0.00         0
#               moulin a cafe       0.83      0.83      0.83        23
#                moustiquaire       0.30      0.75      0.43         4
#                  multiprise       0.00      0.00      0.00         1
#        nettoyage pc tablett       0.82      0.64      0.72        14
#          nettoyeur de vitre       0.90      0.86      0.88        50
#          nettoyeur pression       0.00      0.00      0.00         0
#                  objet deco       0.75      1.00      0.86         6
#             objets lumineux       0.86      0.86      0.86        14
#                    oreiller       0.00      0.00      0.00         5
#         outil multifonction       1.00      1.00      1.00         1
#            outils de jardin       0.53      0.62      0.57        13
#                 ouvre boite       0.00      0.00      0.00         1
#                      paddle       0.00      0.00      0.00         3
#                  paillasson       0.00      0.00      0.00         3
#                      panier       0.85      0.97      0.91        30
#              panier a linge       0.83      0.67      0.74        15
#                     panneau       0.70      0.90      0.79        70
#           panneaux japonais       0.50      0.55      0.52        11
#                      papier       0.92      1.00      0.96        12
#                papier peint       0.83      1.00      0.91         5
#                   parapluie       0.00      0.00      0.00         1
#                     parasol       0.60      1.00      0.75         3
#           parasol chauffant       0.72      0.90      0.80        31
#                    paravent       0.67      1.00      0.80         6
#                        parc       0.00      0.00      0.00         3
#             paroi de douche       0.00      0.00      0.00         0
#               parure de lit       1.00      1.00      1.00         8
#                      patere       0.50      0.91      0.65        11
#                   pc bureau       0.82      0.90      0.86        10
#                 pc portable       0.80      0.80      0.80        10
#                    peignoir       0.67      1.00      0.80         2
#                     peluche       0.36      0.45      0.40        11
#                    penderie       0.68      0.80      0.74        40
#           perceuse visseuse       0.46      0.57      0.51        30
#                     pergola       0.48      0.71      0.57        34
#               pese personne       0.75      1.00      0.86         3
#         petit meuble sejour       0.67      0.67      0.67         3
#             petit outillage       0.45      1.00      0.62         5
#                photo studio       0.00      0.00      0.00         2
#            pieces detachees       0.99      0.99      0.99        82
#               pied de lampe       0.00      0.00      0.00         4
#             pied de parasol       0.20      0.25      0.22         4
#        pile et accumulateur       0.33      0.33      0.33         3
#                     piscine       0.96      0.96      0.96        79
#                  plafonnier       0.84      0.94      0.89        17
#         plafonnier ventilat       0.86      1.00      0.92        18
#                       plaid       0.00      0.00      0.00         3
#             plan de travail       0.75      0.75      0.75        20
#                plan incline       0.50      1.00      0.67         1
#           plaque de cuisson       0.00      0.00      0.00         1
#                plat a cuire       0.00      0.00      0.00         1
#                     plateau       0.00      0.00      0.00         3
#         plateforme vibrante       0.25      0.75      0.38         4
#              platine vinyle       0.78      0.78      0.78        36
#                       poele       0.67      1.00      0.80         2
#             poignee cuisine       0.20      0.50      0.29         2
#                       poire       0.95      1.00      0.97        18
#            pompe d'arrosage       0.67      1.00      0.80         2
#                    ponceuse       0.25      1.00      0.40         2
#                     portant       1.00      0.40      0.57         5
#               porte armoire       0.78      0.78      0.78         9
#                  porte bebe       0.33      1.00      0.50         3
#            porte chaussures       0.44      0.92      0.59        12
#               porte manteau       0.85      1.00      0.92        11
#             porte parapluie       0.91      0.96      0.93        67
#                 porte revue       0.97      0.97      0.97       115
#             porte serviette       0.44      0.50      0.47         8
#          porteur et bascule       0.20      0.20      0.20         5
#    pose encastrable cuisine       1.00      1.00      1.00        10
# pose ensemble salle de bain       0.86      1.00      0.92        12
#      pose evier et mitigeur       0.00      0.00      0.00         6
#              pot jardiniere       0.00      0.00      0.00         2
#               pot toilettes       0.00      0.00      0.00         1
#                     potager       0.57      0.57      0.57         7
#          poubelle a couches       1.00      1.00      1.00        14
#            poubelle cuisine       0.67      1.00      0.80         6
#                poubelle sdb       0.70      0.74      0.72        31
#          pouf / repose pied       0.83      1.00      0.91         5
#            poupee et poupon       1.00      0.80      0.89         5
#                   poussette       0.00      0.00      0.00         9
#              presse agrumes       0.81      1.00      0.89        25
#            prise parafoudre       0.91      0.88      0.90        49
#                  processeur       0.84      0.96      0.90        77
#             protege matelas       0.89      0.91      0.90       200
#            protege oreiller       0.86      0.75      0.80         8
#           protege traversin       0.88      1.00      0.93         7
#                purificateur       0.92      0.96      0.94       255
#                      puzzle       0.50      0.67      0.57         3
#                   radiateur       0.88      1.00      0.94        15
#                    radio cd       0.82      0.91      0.86       115
#                radio reveil       0.95      0.93      0.94        42
#                      rameur       0.77      0.83      0.80        12
#           rangement a poser       0.00      0.00      0.00         1
#            rangement bureau       0.67      0.86      0.75         7
#           rangement chambre       0.92      1.00      0.96        11
#            rangement enfant       0.78      0.82      0.80        17
#               rangement sdb       1.00      0.43      0.60         7
#                rasoir homme       0.95      0.96      0.96       250
#          receveur de douche       0.84      0.89      0.86        36
#        recharge de poubelle       0.81      0.94      0.87        18
#                     rechaud       0.33      0.50      0.40         2
#          recuperateur d'eau       0.70      1.00      0.82         7
#         reducteur toilettes       0.00      0.00      0.00         1
#               refrigerateur       0.00      0.00      0.00         1
#             rehausseur bebe       0.94      1.00      0.97        46
#             reseau sans fil       0.00      0.00      0.00         0
#                      reveil       0.50      0.67      0.57         3
#                      rideau       0.00      0.00      0.00         1
#            rideau de douche       0.62      0.62      0.62         8
#                     robinet       0.00      0.00      0.00         0
#                  robot bebe       0.78      0.78      0.78        41
#            robot de cuisine       0.40      1.00      0.57         2
#            robot de piscine       0.60      0.75      0.67         4
#                     rollers       0.17      1.00      0.29         1
#                         sac       0.00      0.00      0.00         5
#                sac a langer       0.83      0.77      0.80        13
#             sac de couchage       0.50      1.00      0.67         1
#                sac de sport       0.19      1.00      0.32         3
#             sac photo video       0.76      1.00      0.87        13
#                  sacoche pc       1.00      1.00      1.00         2
#             salon de jardin       0.71      0.83      0.77         6
#                   satellite       0.00      0.00      0.00         1
#                       sauna       0.00      0.00      0.00         1
#             scie electrique       0.67      1.00      0.80         2
#               seche cheveux       0.88      0.93      0.90        15
#                 seche linge       0.67      1.00      0.80         2
#             seche serviette       0.84      0.89      0.86        18
#         securite domestique       0.00      0.00      0.00         0
#                     senteur       0.93      1.00      0.96        38
#                  separation       0.58      0.68      0.62        62
#             serre de jardin       0.86      0.80      0.83        54
#               set vaisselle       0.93      0.93      0.93        15
#                   set verre       0.78      1.00      0.88         7
#                  siege auto       0.80      1.00      0.89         4
#                  skateboard       1.00      1.00      1.00         4
#                  smartphone       0.38      0.60      0.46         5
#                     sommier       0.25      0.67      0.36         3
#                sono lumiere       0.84      0.94      0.89        17
#        souffleur aspirateur       0.80      0.89      0.84         9
#                 spa jacuzzi       0.50      0.20      0.29         5
#                    spoterie       0.61      1.00      0.76        11
#               station meteo       0.00      0.00      0.00         1
#            statue de jardin       0.57      0.67      0.62         6
#                    steppeur       0.40      0.31      0.35        13
#               sterilisateur       1.00      0.87      0.93        23
#                     sticker       0.97      0.97      0.97        67
#                       store       0.00      0.00      0.00         0
#                 store banne       0.00      0.00      0.00         2
#
#                    accuracy                           0.80     11163
#                   macro avg       0.53      0.57      0.53     11163
#                weighted avg       0.79      0.80      0.79     11163

# %%
#Inference
class CamembertPredictor:
    def __init__(self, model_path, tokenizer_path, label_encoder_path, max_length=CFG.max_length):
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.max_length = max_length
        
        self.model = CamembertForSequenceClassification.from_pretrained(model_path)
        self.tokenizer = CamembertTokenizer.from_pretrained(tokenizer_path)
        with open(label_encoder_path, "rb") as f:
            self.le = pickle.load(f)
        
        self.model.to(self.device)
        self.model.eval()

    def predict_category_single(self, text):
        encoding = self.tokenizer.encode_plus(
            text,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )
        input_ids = encoding['input_ids'].to(self.device)
        attention_mask = encoding['attention_mask'].to(self.device)
        
        with torch.no_grad():
            outputs = self.model(input_ids, attention_mask=attention_mask)
            prediction = torch.argmax(outputs.logits, dim=1).item()
        
        return self.le.inverse_transform([prediction])[0]

    def predict_category_dataset(self, df, text_column='Libellé produit'):
        df['Predicted_Nature'] = df[text_column].apply(self.predict_category_single)
        return df

# %%
predictor = CamembertPredictor(model_path=f'{CFG.save_dir}/{CFG.model_name}', tokenizer_path=f'{CFG.save_dir}/{CFG.model_name}', label_encoder_path=f'{CFG.save_dir}/{CFG.encoder_name}.pkl')


# Example usage
sample_text = "Table à manger verre quadro transparent blanc"
predicted_category = predictor.predict_category_single(sample_text)
print(f"Predicted category for single text: {predicted_category}")

# Example Dataset
test = pd.read_csv(f'{CFG.base_path}/category_data.csv') #takes more than 40min in GPU 5M Row
sample_test = test.sample(n=50, random_state=42)
predicted_df = predictor.predict_category_dataset(sample_test)
predicted_df.head(20)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Predicted category for single text: table
#                                           Libellé produit  \
# 178910                              refrigerateur combine
# 64871                             televiseur 80 cm hd led
# 384591  simpur relax matelas 140x190 therapy carbone a...
# 3185    vidaxl tapis moderne design de cercles 120 x 1...
# 226294  simpur relax matelas 140x190 real confort epai...
# 161418  bureau coin angle en forme l table angle sello...
# 344816  vasagle coiffeuse avec miroir pliable table de...
# 146338  slide ensemble meubles tv unite murale style m...
# 476151         lave linge sechant ouverture hublot 8 5 kg
# 162177                           matelas mousse 90x190 cm
# 358580                          meuble haut 2 portes 80cm
# 181838                                         lampadaire
# 435640                     cadre a lattes fixe 140x190 cm
# 98597      ateliers t4 lit evolutif 60x120 cm laque blanc
# 394487                        enfilade 3 portes 2 tiroirs
# 56188               protege matelas 180x200cm impermeable
# 348266  lot de 2 tables de chevet 1 tiroir 1 etagere n...
# 73725                        sommier tapissier 160x200 cm
# 79180   platine vinyle victrola bluetooth a 2 vitesses...
# 236498  simpur relax matelas 140x200 visco ergo anatom...
#
#                       Nature      Predicted_Nature
# 178910         refrigerateur         refrigerateur
# 64871          tv ecran plat         tv ecran plat
# 384591   meuble a chaussures               matelas
# 3185    tapis de salon et ch  tapis de salon et ch
# 226294               matelas               matelas
# 161418                bureau                bureau
# 344816             coiffeuse             coiffeuse
# 146338             meuble tv             meuble tv
# 476151            lave linge            lave linge
# 162177               matelas               matelas
# 358580   meuble haut cuisine   meuble haut cuisine
# 181838    lampadaire liseuse            lampadaire
# 435640        cadre a lattes        cadre a lattes
# 98597               lit bebe              lit bebe
# 394487                buffet                buffet
# 56188        protege matelas       protege matelas
# 348266                chevet                chevet
# 73725                sommier               sommier
# 79180         platine vinyle        platine vinyle
# 236498               matelas               matelas
