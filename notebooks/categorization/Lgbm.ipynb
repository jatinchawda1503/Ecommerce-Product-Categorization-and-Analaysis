# %%
import pandas as pd
import numpy as np
import re


from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score
from sklearn.utils.class_weight import compute_class_weight
from sklearn.preprocessing import LabelEncoder

from lightgbm import LGBMClassifier

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import FrenchStemmer


french_stop_words = stopwords.words('french')
stemmer = FrenchStemmer()


file_path = '../../data/ecommerce_sales.xlsb'
sheet_name = '20210614 Ecommerce sales'

# %%
test = pd.read_csv('../../data/category_data.csv')

# %%
data = pd.read_csv('../../data/category_data_unique_title.csv')

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data['Libellé produit'], data['Nature'], test_size=0.20, random_state=42
)

# %%
def clean_and_tokenize(text):  
    text = re.sub(r'[^\w\s]', '', text)
    tokens = word_tokenize(text, language='french')
    tokens = [stemmer.stem(word) for word in tokens if word not in set(french_stop_words)]
    return tokens

# %%
tfidf = TfidfVectorizer(stop_words=french_stop_words, max_features=5000, use_idf=True, analyzer='word', tokenizer=clean_and_tokenize, ngram_range=(1,2))
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)
# Out:
# d:\Users\jatin\.conda\envs\general\Lib\site-packages\sklearn\feature_extraction\text.py:523: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
clf = LGBMClassifier(learning_rate=3e-5, objective='multiclass')
clf.fit(X_train_tfidf, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.328245 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 136803
# [LightGBM] [Info] Number of data points in the train set: 44648, number of used features: 4227
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -6.814744
# [LightGBM] [Info] Start training from score -6.945365
# [LightGBM] [Info] Start training from score -4.683117
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -7.528511
# [LightGBM] [Info] Start training from score -6.006084
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -6.516910
# [LightGBM] [Info] Start training from score -7.873351
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -7.816193
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -6.337117
# [LightGBM] [Info] Start training from score -7.528511
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -5.823763
# [LightGBM] [Info] Start training from score -7.487689
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -8.403980
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -6.091444
# [LightGBM] [Info] Start training from score -7.816193
# [LightGBM] [Info] Start training from score -8.914805
# [LightGBM] [Info] Start training from score -6.755321
# [LightGBM] [Info] Start training from score -6.349856
# [LightGBM] [Info] Start training from score -7.210057
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -6.299846
# [LightGBM] [Info] Start training from score -6.487057
# [LightGBM] [Info] Start training from score -8.914805
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -6.263914
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -7.998515
# [LightGBM] [Info] Start training from score -6.349856
# [LightGBM] [Info] Start training from score -6.992993
# [LightGBM] [Info] Start training from score -8.141615
# [LightGBM] [Info] Start training from score -8.914805
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -5.831367
# [LightGBM] [Info] Start training from score -7.933976
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -6.337117
# [LightGBM] [Info] Start training from score -8.141615
# [LightGBM] [Info] Start training from score -8.067507
# [LightGBM] [Info] Start training from score -6.646122
# [LightGBM] [Info] Start training from score -8.403980
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -7.873351
# [LightGBM] [Info] Start training from score -6.736273
# [LightGBM] [Info] Start training from score -7.873351
# [LightGBM] [Info] Start training from score -7.410728
# [LightGBM] [Info] Start training from score -7.998515
# [LightGBM] [Info] Start training from score -6.877923
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -6.362759
# [LightGBM] [Info] Start training from score -7.615522
# [LightGBM] [Info] Start training from score -6.071836
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -5.801290
# [LightGBM] [Info] Start training from score -7.123046
# [LightGBM] [Info] Start training from score -7.487689
# [LightGBM] [Info] Start training from score -7.933976
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -6.217928
# [LightGBM] [Info] Start training from score -6.835364
# [LightGBM] [Info] Start training from score -6.275748
# [LightGBM] [Info] Start training from score -7.068979
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -7.095647
# [LightGBM] [Info] Start training from score -6.287724
# [LightGBM] [Info] Start training from score -6.015217
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -7.873351
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -8.403980
# [LightGBM] [Info] Start training from score -7.710833
# [LightGBM] [Info] Start training from score -5.808725
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -8.221658
# [LightGBM] [Info] Start training from score -7.448468
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -7.762126
# [LightGBM] [Info] Start training from score -7.933976
# [LightGBM] [Info] Start training from score -6.755321
# [LightGBM] [Info] Start training from score -7.662042
# [LightGBM] [Info] Start training from score -6.375831
# [LightGBM] [Info] Start training from score -6.024434
# [LightGBM] [Info] Start training from score -6.299846
# [LightGBM] [Info] Start training from score -7.816193
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -6.699232
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -7.710833
# [LightGBM] [Info] Start training from score -7.528511
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -8.403980
# [LightGBM] [Info] Start training from score -8.221658
# [LightGBM] [Info] Start training from score -4.450815
# [LightGBM] [Info] Start training from score -7.339269
# [LightGBM] [Info] Start training from score -6.899902
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -5.205307
# [LightGBM] [Info] Start training from score -6.389077
# [LightGBM] [Info] Start training from score -7.448468
# [LightGBM] [Info] Start training from score -8.067507
# [LightGBM] [Info] Start training from score -8.221658
# [LightGBM] [Info] Start training from score -6.945365
# [LightGBM] [Info] Start training from score -6.312116
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -6.856417
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -4.730214
# [LightGBM] [Info] Start training from score -6.101395
# [LightGBM] [Info] Start training from score -3.963684
# [LightGBM] [Info] Start training from score -7.448468
# [LightGBM] [Info] Start training from score -7.448468
# [LightGBM] [Info] Start training from score -5.097093
# [LightGBM] [Info] Start training from score -6.206755
# [LightGBM] [Info] Start training from score -6.547682
# [LightGBM] [Info] Start training from score -7.017685
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -8.914805
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -4.418706
# [LightGBM] [Info] Start training from score -4.366205
# [LightGBM] [Info] Start training from score -7.873351
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -6.646122
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -8.141615
# [LightGBM] [Info] Start training from score -7.272578
# [LightGBM] [Info] Start training from score -7.374360
# [LightGBM] [Info] Start training from score -7.017685
# [LightGBM] [Info] Start training from score -6.240657
# [LightGBM] [Info] Start training from score -6.472458
# [LightGBM] [Info] Start training from score -6.968895
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -6.856417
# [LightGBM] [Info] Start training from score -3.412867
# [LightGBM] [Info] Start training from score -4.291468
# [LightGBM] [Info] Start training from score -7.374360
# [LightGBM] [Info] Start training from score -6.595691
# [LightGBM] [Info] Start training from score -6.629027
# [LightGBM] [Info] Start training from score -6.968895
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -7.305367
# [LightGBM] [Info] Start training from score -4.647442
# [LightGBM] [Info] Start training from score -5.979177
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -7.210057
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -6.563430
# [LightGBM] [Info] Start training from score -7.873351
# [LightGBM] [Info] Start training from score -7.873351
# [LightGBM] [Info] Start training from score -6.024434
# [LightGBM] [Info] Start training from score -5.839030
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -7.068979
# [LightGBM] [Info] Start training from score -5.682684
# [LightGBM] [Info] Start training from score -4.649781
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -5.902544
# [LightGBM] [Info] Start training from score -6.629027
# [LightGBM] [Info] Start training from score -5.268485
# [LightGBM] [Info] Start training from score -7.240829
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -5.553273
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -6.101395
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -8.141615
# [LightGBM] [Info] Start training from score -7.873351
# [LightGBM] [Info] Start training from score -7.571071
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -7.873351
# [LightGBM] [Info] Start training from score -7.816193
# [LightGBM] [Info] Start training from score -6.337117
# [LightGBM] [Info] Start training from score -6.152688
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -6.736273
# [LightGBM] [Info] Start training from score -7.017685
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -5.935880
# [LightGBM] [Info] Start training from score -6.487057
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -7.448468
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -4.868834
# [LightGBM] [Info] Start training from score -5.559070
# [LightGBM] [Info] Start training from score -6.755321
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -7.240829
# [LightGBM] [Info] Start training from score -7.528511
# [LightGBM] [Info] Start training from score -7.615522
# [LightGBM] [Info] Start training from score -6.646122
# [LightGBM] [Info] Start training from score -7.873351
# [LightGBM] [Info] Start training from score -5.676127
# [LightGBM] [Info] Start training from score -8.141615
# [LightGBM] [Info] Start training from score -6.629027
# [LightGBM] [Info] Start training from score -6.579430
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -5.340589
# [LightGBM] [Info] Start training from score -6.337117
# [LightGBM] [Info] Start training from score -7.816193
# [LightGBM] [Info] Start training from score -6.052604
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -7.998515
# [LightGBM] [Info] Start training from score -7.410728
# [LightGBM] [Info] Start training from score -4.514202
# [LightGBM] [Info] Start training from score -6.547682
# [LightGBM] [Info] Start training from score -6.681213
# [LightGBM] [Info] Start training from score -7.210057
# [LightGBM] [Info] Start training from score -8.308670
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -4.452736
# [LightGBM] [Info] Start training from score -5.524781
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -7.571071
# [LightGBM] [Info] Start training from score -7.017685
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -6.375831
# [LightGBM] [Info] Start training from score -8.221658
# [LightGBM] [Info] Start training from score -5.786584
# [LightGBM] [Info] Start training from score -4.659193
# [LightGBM] [Info] Start training from score -6.736273
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -7.710833
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -8.914805
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -6.856417
# [LightGBM] [Info] Start training from score -7.710833
# [LightGBM] [Info] Start training from score -7.068979
# [LightGBM] [Info] Start training from score -6.877923
# [LightGBM] [Info] Start training from score -7.615522
# [LightGBM] [Info] Start training from score -7.240829
# [LightGBM] [Info] Start training from score -6.835364
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -5.588571
# [LightGBM] [Info] Start training from score -5.006121
# [LightGBM] [Info] Start training from score -7.571071
# [LightGBM] [Info] Start training from score -8.221658
# [LightGBM] [Info] Start training from score -8.403980
# [LightGBM] [Info] Start training from score -7.043003
# [LightGBM] [Info] Start training from score -4.224988
# [LightGBM] [Info] Start training from score -5.340589
# [LightGBM] [Info] Start training from score -7.487689
# [LightGBM] [Info] Start training from score -8.308670
# [LightGBM] [Info] Start training from score -7.410728
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -8.914805
# [LightGBM] [Info] Start training from score -8.067507
# [LightGBM] [Info] Start training from score -7.043003
# [LightGBM] [Info] Start training from score -6.081592
# [LightGBM] [Info] Start training from score -6.389077
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -6.992993
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -7.305367
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -6.071836
# [LightGBM] [Info] Start training from score -7.068979
# [LightGBM] [Info] Start training from score -7.123046
# [LightGBM] [Info] Start training from score -7.305367
# [LightGBM] [Info] Start training from score -7.762126
# [LightGBM] [Info] Start training from score -7.151217
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -7.210057
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -5.026392
# [LightGBM] [Info] Start training from score -7.615522
# [LightGBM] [Info] Start training from score -5.054076
# [LightGBM] [Info] Start training from score -6.755321
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -5.331286
# [LightGBM] [Info] Start training from score -5.695929
# [LightGBM] [Info] Start training from score -8.067507
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -6.945365
# [LightGBM] [Info] Start training from score -5.631391
# [LightGBM] [Info] Start training from score -6.922375
# [LightGBM] [Info] Start training from score -3.571674
# [LightGBM] [Info] Start training from score -5.676127
# [LightGBM] [Info] Start training from score -3.979133
# [LightGBM] [Info] Start training from score -8.067507
# [LightGBM] [Info] Start training from score -7.662042
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -6.755321
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -6.240657
# [LightGBM] [Info] Start training from score -7.068979
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -2.941420
# [LightGBM] [Info] Start training from score -4.387597
# [LightGBM] [Info] Start training from score -8.141615
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -7.710833
# [LightGBM] [Info] Start training from score -7.448468
# [LightGBM] [Info] Start training from score -6.532178
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -4.026966
# [LightGBM] [Info] Start training from score -5.625160
# [LightGBM] [Info] Start training from score -6.968895
# [LightGBM] [Info] Start training from score -3.733022
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -5.779311
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -8.308670
# [LightGBM] [Info] Start training from score -6.131854
# [LightGBM] [Info] Start training from score -6.646122
# [LightGBM] [Info] Start training from score -6.835364
# [LightGBM] [Info] Start training from score -5.138220
# [LightGBM] [Info] Start training from score -7.710833
# [LightGBM] [Info] Start training from score -6.312116
# [LightGBM] [Info] Start training from score -7.615522
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -8.914805
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -7.305367
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -7.571071
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -6.814744
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -8.403980
# [LightGBM] [Info] Start training from score -7.615522
# [LightGBM] [Info] Start training from score -4.973224
# [LightGBM] [Info] Start training from score -7.180204
# [LightGBM] [Info] Start training from score -5.878251
# [LightGBM] [Info] Start training from score -6.899902
# [LightGBM] [Info] Start training from score -7.762126
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -6.487057
# [LightGBM] [Info] Start training from score -6.487057
# [LightGBM] [Info] Start training from score -6.402500
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -5.816216
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -6.472458
# [LightGBM] [Info] Start training from score -8.914805
# [LightGBM] [Info] Start training from score -6.324538
# [LightGBM] [Info] Start training from score -7.272578
# [LightGBM] [Info] Start training from score -6.877923
# [LightGBM] [Info] Start training from score -4.992832
# [LightGBM] [Info] Start training from score -6.877923
# [LightGBM] [Info] Start training from score -6.052604
# [LightGBM] [Info] Start training from score -5.433565
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -6.736273
# [LightGBM] [Info] Start training from score -6.071836
# [LightGBM] [Info] Start training from score -8.221658
# [LightGBM] [Info] Start training from score -7.710833
# [LightGBM] [Info] Start training from score -7.410728
# [LightGBM] [Info] Start training from score -5.354707
# [LightGBM] [Info] Start training from score -5.702618
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -5.145883
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -7.998515
# [LightGBM] [Info] Start training from score -7.448468
# [LightGBM] [Info] Start training from score -6.024434
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -5.559070
# [LightGBM] [Info] Start training from score -8.403980
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -4.901430
# [LightGBM] [Info] Start training from score -7.339269
# [LightGBM] [Info] Start training from score -6.968895
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -7.448468
# [LightGBM] [Info] Start training from score -6.195705
# [LightGBM] [Info] Start training from score -7.873351
# [LightGBM] [Info] Start training from score -8.914805
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -6.195705
# [LightGBM] [Info] Start training from score -7.123046
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -6.922375
# [LightGBM] [Info] Start training from score -5.519179
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -7.240829
# [LightGBM] [Info] Start training from score -6.612220
# [LightGBM] [Info] Start training from score -8.403980
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -7.151217
# [LightGBM] [Info] Start training from score -8.403980
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -6.033736
# [LightGBM] [Info] Start training from score -6.629027
# [LightGBM] [Info] Start training from score -5.108143
# [LightGBM] [Info] Start training from score -6.968895
# [LightGBM] [Info] Start training from score -6.794542
# [LightGBM] [Info] Start training from score -8.067507
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -8.403980
# [LightGBM] [Info] Start training from score -5.631391
# [LightGBM] [Info] Start training from score -7.615522
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -7.374360
# [LightGBM] [Info] Start training from score -7.571071
# [LightGBM] [Info] Start training from score -7.095647
# [LightGBM] [Info] Start training from score -7.615522
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -6.856417
# [LightGBM] [Info] Start training from score -6.033736
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -6.275748
# [LightGBM] [Info] Start training from score -5.750738
# [LightGBM] [Info] Start training from score -8.221658
# [LightGBM] [Info] Start training from score -7.528511
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -7.487689
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -4.661559
# [LightGBM] [Info] Start training from score -9.320270
# [LightGBM] [Info] Start training from score -7.487689
# [LightGBM] [Info] Start training from score -8.308670
# [LightGBM] [Info] Start training from score -4.871754
# [LightGBM] [Info] Start training from score -6.416105
# [LightGBM] [Info] Start training from score -6.402500
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -6.121597
# [LightGBM] [Info] Start training from score -8.403980
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -9.607953
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -7.933976
# [LightGBM] [Info] Start training from score -5.502558
# [LightGBM] [Info] Start training from score -8.403980
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -7.816193
# [LightGBM] [Info] Start training from score -6.111445
# [LightGBM] [Info] Start training from score -8.141615
# [LightGBM] [Info] Start training from score -8.914805
# [LightGBM] [Info] Start training from score -7.528511
# [LightGBM] [Info] Start training from score -7.933976
# [LightGBM] [Info] Start training from score -6.968895
# [LightGBM] [Info] Start training from score -7.339269
# [LightGBM] [Info] Start training from score -6.595691
# [LightGBM] [Info] Start training from score -7.487689
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -5.130616
# [LightGBM] [Info] Start training from score -4.413146
# [LightGBM] [Info] Start training from score -7.180204
# [LightGBM] [Info] Start training from score -7.571071
# [LightGBM] [Info] Start training from score -6.699232
# [LightGBM] [Info] Start training from score -6.835364
# [LightGBM] [Info] Start training from score -8.914805
# [LightGBM] [Info] Start training from score -7.933976
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -8.914805
# [LightGBM] [Info] Start training from score -7.448468
# [LightGBM] [Info] Start training from score -6.375831
# [LightGBM] [Info] Start training from score -8.308670
# [LightGBM] [Info] Start training from score -6.071836
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -8.221658
# [LightGBM] [Info] Start training from score -7.933976
# [LightGBM] [Info] Start training from score -8.914805
# [LightGBM] [Info] Start training from score -6.252217
# [LightGBM] [Info] Start training from score -5.449069
# [LightGBM] [Info] Start training from score -4.935124
# [LightGBM] [Info] Start training from score -3.989970
# [LightGBM] [Info] Start training from score -7.410728
# [LightGBM] [Info] Start training from score -7.240829
# [LightGBM] [Info] Start training from score -3.801814
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -7.710833
# [LightGBM] [Info] Start training from score -6.516910
# [LightGBM] [Info] Start training from score -4.668694
# [LightGBM] [Info] Start training from score -5.935880
# [LightGBM] [Info] Start training from score -7.017685
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -7.210057
# [LightGBM] [Info] Start training from score -7.210057
# [LightGBM] [Info] Start training from score -6.362759
# [LightGBM] [Info] Start training from score -8.403980
# [LightGBM] [Info] Start training from score -3.794817
# [LightGBM] [Info] Start training from score -5.854535
# [LightGBM] [Info] Start training from score -6.362759
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -7.662042
# [LightGBM] [Info] Start training from score -8.509340
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -5.177136
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -8.914805
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -7.571071
# [LightGBM] [Info] Start training from score -8.403980
# [LightGBM] [Info] Start training from score -5.508068
# [LightGBM] [Info] Start training from score -7.933976
# [LightGBM] [Info] Start training from score -7.998515
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Info] Start training from score -8.308670
# [LightGBM] [Info] Start training from score -8.914805
# [LightGBM] [Info] Start training from score -7.017685
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -8.221658
# [LightGBM] [Info] Start training from score -6.968895
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -10.706565
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -8.760655
# [LightGBM] [Info] Start training from score -6.899902
# [LightGBM] [Info] Start training from score -6.663514
# [LightGBM] [Info] Start training from score -8.627123
# [LightGBM] [Info] Start training from score -6.681213
# [LightGBM] [Info] Start training from score -8.914805
# [LightGBM] [Info] Start training from score -5.588571
# [LightGBM] [Info] Start training from score -5.205307
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -5.403260
# [LightGBM] [Info] Start training from score -6.736273
# [LightGBM] [Info] Start training from score -6.835364
# [LightGBM] [Info] Start training from score -7.662042
# [LightGBM] [Info] Start training from score -7.448468
# [LightGBM] [Info] Start training from score -7.662042
# [LightGBM] [Info] Start training from score -7.068979
# [LightGBM] [Info] Start training from score -6.899902
# [LightGBM] [Info] Start training from score -7.528511
# [LightGBM] [Info] Start training from score -8.403980
# [LightGBM] [Info] Start training from score -6.755321
# [LightGBM] [Info] Start training from score -10.013418
# [LightGBM] [Info] Start training from score -7.762126
# [LightGBM] [Info] Start training from score -6.487057
# [LightGBM] [Info] Start training from score -6.416105
# [LightGBM] [Info] Start training from score -5.277219
# [LightGBM] [Info] Start training from score -8.141615
# [LightGBM] [Info] Start training from score -9.097127
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMClassifier(learning_rate=3e-05, objective='multiclass')

# %%
y_pred = clf.predict(X_test_tfidf)

# %%
print("Model performance:")
print(classification_report(y_test, y_pred))
# Out:
# Model performance:
# d:\Users\jatin\.conda\envs\general\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
#             velo fitness       0.00      0.00      0.00        17
#              ventilateur       0.00      0.00      0.00         9
#                    verre       0.00      0.00      0.00         5
#                vestiaire       0.00      0.00      0.00        11
#        vetement de sport       0.00      0.00      0.00         1
#          videoprojecteur       0.00      0.00      0.00         6
#     visserie consommable       0.00      0.00      0.00        13
#                  vitrine       0.00      0.00      0.00        23
#                  voilage       0.00      0.00      0.00        67
#                   webcam       0.00      0.00      0.00         2
#
#                 accuracy                           0.05     11163
#                macro avg       0.00      0.00      0.00     11163
#             weighted avg       0.00      0.05      0.01     11163
# d:\Users\jatin\.conda\envs\general\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\Users\jatin\.conda\envs\general\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.0546448087431694

# %%
pred_y_df = pd.DataFrame({'x_test': X_test,'y_pred': y_pred, 'y_test':y_test})
pred_y_df
# Out:
#                                                   x_test   y_pred  \
# 23352  lot de 2 chaises velours gris et pieds metal n...  matelas
# 20787   matelas merinos mimic 90x190 cm matelas ressorts  matelas
# 971             drap plat uni en coton 240 x 290 cm bleu  matelas
# 3914                 canape droit convertible 2 5 places  matelas
# 21339  pack complet lit tiroir junior petit elephant ...  matelas
# ...                                                  ...      ...
# 624             altolattes sommier 2x20 lattes 140x190cm  matelas
# 9846   cible jeu de flechettes electronique 27 jeux j...  matelas
# 7990   housse de couette 220x240 cm avec ses 2 taies ...  matelas
# 18337  chaise fauteuil scandinave frida tissu gris clair  matelas
# 13571  armoire de toilette bambou sicela 58 x h 51 cm...  matelas
#
#                   y_test
# 23352             chaise
# 20787            matelas
# 971          drap housse
# 3914        canape droit
# 21339   ensemble chambre
# ...                  ...
# 624              sommier
# 9846   jeu de flechettes
# 7990   housse de couette
# 18337           fauteuil
# 13571      rangement sdb
#
# [11163 rows x 3 columns]

# %%
X_all_tfidf = tfidf.transform(data['Libellé produit'])
all_pred = clf.predict(X_all_tfidf)
data['Predicted_Category'] = all_pred

# %%
data['Differently_Categorized'] = data['Nature'] != data['Predicted_Category']

# %%
data['Recategorized_Nature'] = data['Predicted_Category']

# %%
# Print statistics
print("Number of differently categorized items:", data['Differently_Categorized'].sum())
print("Percentage of differently categorized items: {:.2f}%".format(data['Differently_Categorized'].mean() * 100))

# Display some examples of recategorized items
print("\nExamples of recategorized items:")
print(data[data['Differently_Categorized']][['Libellé produit', 'Nature', 'Recategorized_Nature']].head(10))
# Out:
# Number of differently categorized items: 52844
# Percentage of differently categorized items: 94.68%
#
# Examples of recategorized items:
#                                      Libellé produit               Nature  \
# 0       table basse carree detroit design industriel          table basse
# 1                  ours en peluche geant 150 cm brun              peluche
# 2                 ours en peluche geant 100 cm blanc              peluche
# 3    lot de 4 chaises mia noires pour salle a manger               chaise
# 4                 meuble tv falko bois blanc et gris            meuble tv
# 5  meuble a chaussures imitation h tre 3 portes b...  meuble a chaussures
# 6  meuble a chaussures gris 3 portes blanches ave...  meuble a chaussures
# 7   tagere a double position tania bois imitation...         bibliotheque
# 8  table a manger georgia 6 personnes blanche et ...                table
# 9            console vintage leoni motifs graphiques               bureau
#
#   Recategorized_Nature
# 0              matelas
# 1              matelas
# 2              matelas
# 3              matelas
# 4              matelas
# 5              matelas
# 6              matelas
# 7              matelas
# 8              matelas
# 9              matelas
